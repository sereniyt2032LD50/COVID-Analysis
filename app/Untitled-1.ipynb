# %% [markdown]
# ### Covid Data Analysis
# ##### 0. Install and Import Dependencies

# %%
#pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\HP\Documents\python_world\COVID-Analysis\data\vaccination-metadata.csv")

data.head()
# Out:
#   ISO3                 VACCINE_NAME PRODUCT_NAME     COMPANY_NAME  \
# 0  SHN        AstraZeneca - AZD1222      AZD1222      AstraZeneca
# 1  GRL          Moderna - mRNA-1273    mRNA-1273          Moderna
# 2  FRO          Moderna - mRNA-1273    mRNA-1273          Moderna
# 3  FRO  Pfizer BioNTech - Comirnaty    Comirnaty  Pfizer BioNTech
# 4  BIH        AstraZeneca - AZD1222      AZD1222      AstraZeneca
#
#   AUTHORIZATION_DATE START_DATE  END_DATE  COMMENT DATA_SOURCE
# 0                NaN        NaN       NaN      NaN        OWID
# 1                NaN        NaN       NaN      NaN        OWID
# 2                NaN        NaN       NaN      NaN        OWID
# 3                NaN        NaN       NaN      NaN        OWID
# 4                NaN        NaN       NaN      NaN        OWID

# %%
data.isnull().sum()
# Out:
# ISO3                     0
# VACCINE_NAME             0
# PRODUCT_NAME             1
# COMPANY_NAME            47
# AUTHORIZATION_DATE     610
# START_DATE             286
# END_DATE              1100
# COMMENT               1100
# DATA_SOURCE              0
# dtype: int64

# %%
print(data.fillna({'COMPANY_NAME':'Missing'}, inplace=True))
data.isnull().sum()
# Out:
# None
# ISO3                     0
# VACCINE_NAME             0
# PRODUCT_NAME             1
# COMPANY_NAME             0
# AUTHORIZATION_DATE     610
# START_DATE             286
# END_DATE              1100
# COMMENT               1100
# DATA_SOURCE              0
# dtype: int64

# %%
data['START_DATE'].fillna('Missing', inplace=True)
data.isnull().sum()
# Out:
# ISO3                     0
# VACCINE_NAME             0
# PRODUCT_NAME             1
# COMPANY_NAME             0
# AUTHORIZATION_DATE     610
# START_DATE               0
# END_DATE              1100
# COMMENT               1100
# DATA_SOURCE              0
# dtype: int64

# %%
data.keys()
# Out:
# Index(['ISO3', 'VACCINE_NAME', 'PRODUCT_NAME', 'COMPANY_NAME',
#        'AUTHORIZATION_DATE', 'START_DATE', 'END_DATE', 'COMMENT',
#        'DATA_SOURCE'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COUNTRY                               229 non-null    object
#  1   ISO3                                  229 non-null    object
#  2   WHO_REGION                            229 non-null    object
#  3   DATA_SOURCE                           229 non-null    object
#  4   DATE_UPDATED                          229 non-null    object
#  5   TOTAL_VACCINATIONS                    228 non-null    float64
#  6   PERSONS_VACCINATED_1PLUS_DOSE         229 non-null    int64
#  7   TOTAL_VACCINATIONS_PER100             227 non-null    float64
#  8   PERSONS_VACCINATED_1PLUS_DOSE_PER100  229 non-null    float64
#  9   PERSONS_LAST_DOSE                     229 non-null    int64
#  10  PERSONS_LAST_DOSE_PER100              229 non-null    float64
# ...

# %%
data['VACCINES_USED'].value_counts(dropna = False)
# Out:
# VACCINES_USED
# NaN    229
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (229, 16)

# %%
df = pd.read_csv(r'C:\Users\HP\Documents\python_world\COVID-Analysis\data\vaccination-metadata.csv')
df.tail()
# Out:
#      ISO3                                       VACCINE_NAME  \
# 1095  CZE  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1096  DEU  Moderna – Spikevax Bivalent Original/Omicron  ...
# 1097  SVN  Moderna – Spikevax Bivalent Original/Omicron  ...
# 1098  DEU  Pfizer BioNTech - Comirnaty Bivalent Original/...
# 1099  SVN  Pfizer BioNTech - Comirnaty Bivalent Original/...
#
#                                            PRODUCT_NAME COMPANY_NAME  \
# 1095      Comirnaty Bivalent Original/Omicron BA.4/BA.5          NaN
# 1096  Moderna – Spikevax Bivalent Original/Omicron  ...          NaN
# 1097  Moderna – Spikevax Bivalent Original/Omicron  ...          NaN
# 1098  Pfizer BioNTech - Comirnaty Bivalent Original/...          NaN
# 1099  Pfizer BioNTech - Comirnaty Bivalent Original/...          NaN
#
#      AUTHORIZATION_DATE  START_DATE  END_DATE  COMMENT DATA_SOURCE
# 1095                NaN  2022-10-05       NaN      NaN   REPORTING
# ...

# %%
df.head(20)
# Out:
#    ISO3                 VACCINE_NAME  PRODUCT_NAME  \
# 0   SHN        AstraZeneca - AZD1222       AZD1222
# 1   GRL          Moderna - mRNA-1273     mRNA-1273
# 2   FRO          Moderna - mRNA-1273     mRNA-1273
# 3   FRO  Pfizer BioNTech - Comirnaty     Comirnaty
# 4   BIH        AstraZeneca - AZD1222       AZD1222
# 5   BIH  Pfizer BioNTech - Comirnaty     Comirnaty
# 6   BIH          Sinovac - CoronaVac     Coronavac
# 7   JEY          Moderna - mRNA-1273     mRNA-1273
# 8   JEY        AstraZeneca - AZD1222       AZD1222
# 9   JEY  Pfizer BioNTech - Comirnaty     Comirnaty
# 10  GGY          Moderna - mRNA-1273     mRNA-1273
# 11  GGY        AstraZeneca - AZD1222       AZD1222
# 12  GGY  Pfizer BioNTech - Comirnaty     Comirnaty
# 13  GIB        AstraZeneca - AZD1222       AZD1222
# 14  GIB  Pfizer BioNTech - Comirnaty     Comirnaty
# 15  TUR  Pfizer BioNTech - Comirnaty     Comirnaty
# 16  TUR          Sinovac - CoronaVac     Coronavac
# ...

# %%
#Grouping Data by company name and product name

df.groupby('COMPANY_NAME')['PRODUCT_NAME'].value_counts()
# Out:
# COMPANY_NAME                                       PRODUCT_NAME
# Anhui Zhifei Longcom Biopharmaceutical             Zifivax                             3
# AstraZeneca                                        Vaxzevria                         140
#                                                    AZD1222                             7
# Beijing Bio-Institute Biological Products (CNBG)   BBIBP-CorV                        101
# Bharat Biotech                                     Covaxin                            33
# Biological E                                       Corbevax                            1
# CanSino Biologicals                                Convidecia                         28
# Center for Genetic Engineering and Biotechnology   CIGB-66                             5
# Chumakov                                           Covi-Vac                            1
# Gamaleya Research Institute                        Gam-Covid-Vac                      68
# ...

# %%
df['COMPANY_NAME'].value_counts()
# Out:
# COMPANY_NAME
# Pfizer BioNTech                                      174
# AstraZeneca                                          147
# Moderna                                              129
# Janssen Pharmaceuticals                              125
# Beijing Bio-Institute Biological Products (CNBG)     101
# Gamaleya Research Institute                           99
# Serum Institute of India                              92
# Sinovac                                               65
# Bharat Biotech                                        33
# Novavax                                               31
# CanSino Biologicals                                   28
# Instituto Finlay de Vacunas                            6
# Center for Genetic Engineering and Biotechnology       5
# Anhui Zhifei Longcom Biopharmaceutical                 3
# Wuhan Institute of Biological Products (CNBG)          3
# Research Institute for Biological Safety Problems      3
# ...

# %%
df['COMPANY_NAME'].value_counts().loc[lambda x : x>10 ]
# Out:
# COMPANY_NAME
# Pfizer BioNTech                                     174
# AstraZeneca                                         147
# Moderna                                             129
# Janssen Pharmaceuticals                             125
# Beijing Bio-Institute Biological Products (CNBG)    101
# Gamaleya Research Institute                          99
# Serum Institute of India                             92
# Sinovac                                              65
# Bharat Biotech                                       33
# Novavax                                              31
# CanSino Biologicals                                  28
# Name: count, dtype: int64

# %%
# Best use of head or lambda function
df['COMPANY_NAME'].value_counts().head(11)
# Out:
# COMPANY_NAME
# Pfizer BioNTech                                     174
# AstraZeneca                                         147
# Moderna                                             129
# Janssen Pharmaceuticals                             125
# Beijing Bio-Institute Biological Products (CNBG)    101
# Gamaleya Research Institute                          99
# Serum Institute of India                             92
# Sinovac                                              65
# Bharat Biotech                                       33
# Novavax                                              31
# CanSino Biologicals                                  28
# Name: count, dtype: int64

# %%
df.keys()
# Out:
# Index(['ISO3', 'VACCINE_NAME', 'PRODUCT_NAME', 'COMPANY_NAME',
#        'AUTHORIZATION_DATE', 'START_DATE', 'END_DATE', 'COMMENT',
#        'DATA_SOURCE'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ISO3                1100 non-null   object
#  1   VACCINE_NAME        1100 non-null   object
#  2   PRODUCT_NAME        1099 non-null   object
#  3   COMPANY_NAME        1053 non-null   object
#  4   AUTHORIZATION_DATE  490 non-null    object
#  5   START_DATE          814 non-null    object
#  6   END_DATE            0 non-null      float64
#  7   COMMENT             0 non-null      float64
#  8   DATA_SOURCE         1100 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 77.5+ KB

# %%
df['VACCINE_NAME']

# %%
df['VACCINE_NAME'].value_counts()
# Out:
# VACCINE_NAME
# Pfizer BioNTech - Comirnaty                                        174
# AstraZeneca - Vaxzevria                                            140
# Janssen - Ad26.COV 2-S                                             125
# Moderna - Spikevax                                                 124
# Beijing CNBG - BBIBP-CorV                                          101
# SII - Covishield                                                    92
# Gamaleya - Gam-Covid-Vac                                            68
# Sinovac - CoronaVac                                                 65
# Bharat - Covaxin                                                    33
# Novavax-NUVAXOVID                                                   31
# Gamaleya - Sputnik-Light                                            31
# CanSino - Convidecia                                                28
# Pfizer BioNTech - Comirnaty Bivalent Original/Omicron BA.4/BA.5     11
# ...

# %%
plt.style.use('fivethirtyeight')

df['VACCINE_NAME'].value_counts().sort_values(ascending = False).head(5).plot.barh()
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\HP\\Documents\\python_world\\COVID-Analysis\\.venv\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
df['VACCINE_NAME'].value_counts(ascending = False).head(5).plot.barh(figsize=(12,4))
# Out:
# <Axes: ylabel='VACCINE_NAME'>

# %%
df['VACCINE_NAME'].value_counts(ascending = False).head(5).plot.pie(figsize=(11,4))
# Out:
# <Axes: ylabel='count'>

# %%
df['VACCINE_NAME'].value_counts(ascending = False).head(15).plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df['VACCINE_NAME'].value_counts(ascending = False).head(5).values
# Out:
# array([174, 140, 125, 124, 101], dtype=int64)

# %%
df['VACCINE_NAME'].value_counts(ascending = False).head(5).index
# Out:
# Index(['Pfizer BioNTech - Comirnaty', 'AstraZeneca - Vaxzevria',
#        'Janssen - Ad26.COV 2-S', 'Moderna - Spikevax',
#        'Beijing CNBG - BBIBP-CorV'],
#       dtype='object', name='VACCINE_NAME')

# %%
#Grouping Data by Region and vaccine use

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COUNTRY                               229 non-null    object
#  1   ISO3                                  229 non-null    object
#  2   WHO_REGION                            229 non-null    object
#  3   DATA_SOURCE                           229 non-null    object
#  4   DATE_UPDATED                          229 non-null    object
#  5   TOTAL_VACCINATIONS                    228 non-null    float64
#  6   PERSONS_VACCINATED_1PLUS_DOSE         229 non-null    int64
#  7   TOTAL_VACCINATIONS_PER100             227 non-null    float64
#  8   PERSONS_VACCINATED_1PLUS_DOSE_PER100  229 non-null    float64
#  9   PERSONS_LAST_DOSE                     229 non-null    int64
#  10  PERSONS_LAST_DOSE_PER100              229 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')


plt.plot(data['DATE_UPDATED'], data['TOTAL_VACCINATIONS'])
plt.plot(data['DATE_UPDATED'],data['PERSONS_VACCINATED_1PLUS_DOSE'])
plt.title('Slack Vaccine Plot')
plt.xlabel('Date')
plt.ylabel('Vaccine')

plt.tight_layout()
plt.show()
